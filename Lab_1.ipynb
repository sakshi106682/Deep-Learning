# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshi106682/Deep-Learning/blob/main/Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/data/Height_Weight_Data.csv')

# %%
data.head()
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971

# %%
data.describe()
# Out:
#               Index  Height(Inches)  Weight(Pounds)
# count  25000.000000    25000.000000    25000.000000
# mean   12500.500000       67.993114      127.079421
# std     7217.022701        1.901679       11.660898
# min        1.000000       60.278360       78.014760
# 25%     6250.750000       66.704397      119.308675
# 50%    12500.500000       67.995700      127.157750
# 75%    18750.250000       69.272958      134.892850
# max    25000.000000       75.152800      170.924000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Index'].plot(kind='hist', bins=20, title='Index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Height(Inches)'].plot(kind='hist', bins=20, title='Height(Inches)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
import skimage as ski
image=ski.data.coins()
edges=ski.filters.sobel(image)
ski.io.imshow(edges)
ski.io.show()

# %%
import skimage as ski

from skimage import io
image = io.imread('/content/drive/MyDrive/data/image.jpg')
if len(image.shape) == 3:
    image=color.rgb2gray(image)
edges = ski.filters.sobel(image)
ski.io.imshow(edges)
ski.io.show()

# %%
import skimage as ski
from skimage import io
image = io.imread('/content/drive/MyDrive/data/image.jpg')
from skimage.filters import gaussian
smoothed = gaussian(image, sigma=1)
ski.io.imshow(smoothed)
ski.io.show()

# %%
import skimage as ski
from skimage import io,color
image = io.imread('/content/drive/MyDrive/data/image.jpg')
if len(image.shape) == 3:
    image=color.rgb2gray(image)

from skimage.filters import median
from skimage.morphology import disk
filtered = median(image,disk(3))
ski.io.imshow(filtered)
ski.io.show()

# %%
import skimage as ski
from skimage import io
image = io.imread('/content/drive/MyDrive/data/image.jpg')
if len(image.shape) == 3:
    image=color.rgb2gray(image)

from skimage.filters import prewitt
edges=prewitt(image)
ski.io.imshow(edges)
ski.io.show()

# %%
import skimage as ski
from skimage import io
image = io.imread('/content/drive/MyDrive/data/image.jpg')
if len(image.shape) == 3:
    image=color.rgb2gray(image)
from skimage.filters import roberts
edges = roberts(image)
ski.io.imshow(edges)
ski.io.show()
